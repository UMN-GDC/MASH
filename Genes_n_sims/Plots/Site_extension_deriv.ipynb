# %%
# Define random effects
var('A S I')
X = vector([A, S, I])
var('g s e')
sigma = vector([g, s, e]).column()

# Define PC effects
var('pc1 pc2 pc3')
P = vector([pc1, pc2, pc3])
var('d1 d2 d3')
Delta = vector([d1, d2, d3]).column()

# %%
norm(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/lib/python3.8/site-packages/sage/matrix/matrix0.pyx in sage.matrix.matrix0.Matrix.change_ring (build/cythonized/sage/matrix/matrix0.c:11311)()
#    1644         try:
# -> 1645             return self._change_ring(ring)
#    1646         except (AttributeError, NotImplementedError):
#
# ~/miniconda3/lib/python3.8/site-packages/sage/structure/element.pyx in sage.structure.element.Element.__getattr__ (build/cythonized/sage/structure/element.c:4714)()
#     492         """
# --> 493         return self.getattr_from_category(name)
#     494
#
# ~/miniconda3/lib/python3.8/site-packages/sage/structure/element.pyx in sage.structure.element.Element.getattr_from_category (build/cythonized/sage/structure/element.c:4826)()
#     505             cls = P._abstract_element_class
# ...

# %%
X
# Out:
# [a]
# [s]
# [i]
